-- %% [markdown]
-- # [Quiz_Management]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [Quiz_Management]    Script Date: 07-03-2025 10:30:55 PM ******/
CREATE DATABASE [Quiz_Management]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'Quiz_Management', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\Quiz_Management.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'Quiz_Management_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\Quiz_Management_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [Quiz_Management] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [Quiz_Management].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [Quiz_Management] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [Quiz_Management] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [Quiz_Management] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [Quiz_Management] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [Quiz_Management] SET ARITHABORT OFF 
GO
ALTER DATABASE [Quiz_Management] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [Quiz_Management] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [Quiz_Management] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [Quiz_Management] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [Quiz_Management] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [Quiz_Management] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [Quiz_Management] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [Quiz_Management] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [Quiz_Management] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [Quiz_Management] SET  ENABLE_BROKER 
GO
ALTER DATABASE [Quiz_Management] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [Quiz_Management] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [Quiz_Management] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [Quiz_Management] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [Quiz_Management] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [Quiz_Management] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [Quiz_Management] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [Quiz_Management] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [Quiz_Management] SET  MULTI_USER 
GO
ALTER DATABASE [Quiz_Management] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [Quiz_Management] SET DB_CHAINING OFF 
GO
ALTER DATABASE [Quiz_Management] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [Quiz_Management] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [Quiz_Management] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [Quiz_Management] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [Quiz_Management] SET QUERY_STORE = ON
GO
ALTER DATABASE [Quiz_Management] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[MST_Question]

-- %%
USE [Quiz_Management]
GO

-- %%
/****** Object:  Table [dbo].[MST_Question]    Script Date: 07-03-2025 10:30:55 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MST_Question](
	[QuestionID] [int] IDENTITY(1,1) NOT NULL,
	[QuestionText] [nvarchar](max) NULL,
	[QuestionLevelID] [int] NULL,
	[OptionA] [nvarchar](50) NULL,
	[OptionB] [nvarchar](50) NULL,
	[OptionC] [nvarchar](50) NULL,
	[OptionD] [nvarchar](50) NULL,
	[CorrectOption] [nvarchar](50) NULL,
	[QuestionMarks] [int] NULL,
	[IsActive] [bit] NULL,
	[UserID] [int] NULL,
	[Created] [datetime] NULL,
	[Modified] [datetime] NULL,
 CONSTRAINT [PK_MST_Question] PRIMARY KEY CLUSTERED 
(
	[QuestionID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MST_QuestionLevel]

-- %%
/****** Object:  Table [dbo].[MST_QuestionLevel]    Script Date: 07-03-2025 10:30:55 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MST_QuestionLevel](
	[QuestionLevelID] [int] IDENTITY(1,1) NOT NULL,
	[QuestionLevel] [nvarchar](50) NULL,
	[UserID] [int] NULL,
	[Created] [datetime] NULL,
	[Modified] [datetime] NULL,
 CONSTRAINT [PK_MST_QuestionLevel] PRIMARY KEY CLUSTERED 
(
	[QuestionLevelID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MST_Quiz]

-- %%
/****** Object:  Table [dbo].[MST_Quiz]    Script Date: 07-03-2025 10:30:55 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MST_Quiz](
	[QuizID] [int] IDENTITY(1,1) NOT NULL,
	[QuizName] [nvarchar](100) NULL,
	[TotalQuestions] [int] NULL,
	[QuizDate] [datetime] NULL,
	[UserID] [int] NULL,
	[Created] [datetime] NULL,
	[Modified] [datetime] NULL,
 CONSTRAINT [PK_MST_Quiz] PRIMARY KEY CLUSTERED 
(
	[QuizID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MST_QuizWiseQuestions]

-- %%
/****** Object:  Table [dbo].[MST_QuizWiseQuestions]    Script Date: 07-03-2025 10:30:55 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MST_QuizWiseQuestions](
	[QuizWiseQuestionsID] [int] IDENTITY(1,1) NOT NULL,
	[QuizID] [int] NULL,
	[QuestionID] [int] NULL,
	[UserID] [int] NULL,
	[Created] [datetime] NULL,
	[Modified] [datetime] NULL,
 CONSTRAINT [PK_MST_QuizWiseQuestions] PRIMARY KEY CLUSTERED 
(
	[QuizWiseQuestionsID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MST_User]

-- %%
/****** Object:  Table [dbo].[MST_User]    Script Date: 07-03-2025 10:30:55 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MST_User](
	[UserID] [int] IDENTITY(1,1) NOT NULL,
	[UserName] [nvarchar](100) NULL,
	[Password] [nvarchar](100) NULL,
	[Email] [nvarchar](100) NULL,
	[Mobile] [nvarchar](100) NULL,
	[IsActive] [bit] NULL,
	[IsAdmin] [bit] NULL,
	[Created] [datetime] NULL,
	[Modified] [datetime] NULL,
 CONSTRAINT [PK_MST_User] PRIMARY KEY CLUSTERED 
(
	[UserID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF_MST_Question_IsActive]

-- %%
ALTER TABLE [dbo].[MST_Question] ADD  CONSTRAINT [DF_MST_Question_IsActive]  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF_MST_Question_Created]

-- %%
ALTER TABLE [dbo].[MST_Question] ADD  CONSTRAINT [DF_MST_Question_Created]  DEFAULT (getdate()) FOR [Created]
GO

-- %% [markdown]
-- # [DF_MST_QuestionLevel_Created]

-- %%
ALTER TABLE [dbo].[MST_QuestionLevel] ADD  CONSTRAINT [DF_MST_QuestionLevel_Created]  DEFAULT (getdate()) FOR [Created]
GO

-- %% [markdown]
-- # [Created]

-- %%
ALTER TABLE [dbo].[MST_Quiz] ADD  CONSTRAINT [Created]  DEFAULT (getdate()) FOR [Created]
GO

-- %% [markdown]
-- # [Modified]

-- %%
ALTER TABLE [dbo].[MST_Quiz] ADD  CONSTRAINT [Modified]  DEFAULT (getdate()) FOR [Modified]
GO

-- %% [markdown]
-- # [DF_MST_QuizWiseQuestions_Created]

-- %%
ALTER TABLE [dbo].[MST_QuizWiseQuestions] ADD  CONSTRAINT [DF_MST_QuizWiseQuestions_Created]  DEFAULT (getdate()) FOR [Created]
GO

-- %% [markdown]
-- # [DF_MST_User_Created]

-- %%
ALTER TABLE [dbo].[MST_User] ADD  CONSTRAINT [DF_MST_User_Created]  DEFAULT (getdate()) FOR [Created]
GO

-- %% [markdown]
-- # [FK_MST_Question_MST_QuestionLevel]

-- %%
ALTER TABLE [dbo].[MST_Question]  WITH CHECK ADD  CONSTRAINT [FK_MST_Question_MST_QuestionLevel] FOREIGN KEY([QuestionLevelID])
REFERENCES [dbo].[MST_QuestionLevel] ([QuestionLevelID])
GO
ALTER TABLE [dbo].[MST_Question] CHECK CONSTRAINT [FK_MST_Question_MST_QuestionLevel]
GO

-- %% [markdown]
-- # [FK_MST_QuestionLevel_MST_User]

-- %%
ALTER TABLE [dbo].[MST_QuestionLevel]  WITH CHECK ADD  CONSTRAINT [FK_MST_QuestionLevel_MST_User] FOREIGN KEY([UserID])
REFERENCES [dbo].[MST_User] ([UserID])
GO
ALTER TABLE [dbo].[MST_QuestionLevel] CHECK CONSTRAINT [FK_MST_QuestionLevel_MST_User]
GO

-- %% [markdown]
-- # [FK_MST_Quiz_MST_Quiz]

-- %%
ALTER TABLE [dbo].[MST_Quiz]  WITH CHECK ADD  CONSTRAINT [FK_MST_Quiz_MST_Quiz] FOREIGN KEY([UserID])
REFERENCES [dbo].[MST_User] ([UserID])
GO
ALTER TABLE [dbo].[MST_Quiz] CHECK CONSTRAINT [FK_MST_Quiz_MST_Quiz]
GO

-- %% [markdown]
-- # [FK_MST_QuizWiseQuestions_MST_User]

-- %%
ALTER TABLE [dbo].[MST_QuizWiseQuestions]  WITH CHECK ADD  CONSTRAINT [FK_MST_QuizWiseQuestions_MST_User] FOREIGN KEY([UserID])
REFERENCES [dbo].[MST_User] ([UserID])
GO
ALTER TABLE [dbo].[MST_QuizWiseQuestions] CHECK CONSTRAINT [FK_MST_QuizWiseQuestions_MST_User]
GO

-- %% [markdown]
-- # [dbo].[PR_MST_Question_Count]

-- %%
/****** Object:  StoredProcedure [dbo].[PR_MST_Question_Count]    Script Date: 07-03-2025 10:30:55 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[PR_MST_Question_Count]
@UserID INT
AS
BEGIN 
		SELECT COUNT([MST_Question].QuestionID) as 'Count'
		FROM [MST_Question]
		WHERE [MST_Question].UserID = @UserID

END
GO

-- %% [markdown]
-- # [dbo].[PR_MST_Question_DeleteByPk]

-- %%
/****** Object:  StoredProcedure [dbo].[PR_MST_Question_DeleteByPk]    Script Date: 07-03-2025 10:30:55 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[PR_MST_Question_DeleteByPk]
	@QuestionID INT
AS
BEGIN
	DELETE FROM [MST_Question]
	WHERE [MST_Question].QuestionId = @QuestionID
END
GO

-- %% [markdown]
-- # [dbo].[PR_MST_Question_Insert]

-- %%
/****** Object:  StoredProcedure [dbo].[PR_MST_Question_Insert]    Script Date: 07-03-2025 10:30:55 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[PR_MST_Question_Insert]
	@QuestionText		NVARCHAR(50),
	@QuestionLevelID	INT,
	@OptionA			NVARCHAR(50),
	@OptionB			NVARCHAR(50),
	@OptionC			NVARCHAR(50),
	@OptionD			NVARCHAR(50),
	@CorrectOption		NVARCHAR(50),
	@QuestionMarks		INT,
	@UserID				INT,
	@Created			DATETIME,
	@Modified			DATETIME
AS
BEGIN
	INSERT INTO [MST_Question]
	(
		QuestionText,
		QuestionLevelID,
		OptionA,
		OptionB,
		OptionC,
		OptionD,
		CorrectOption,
		QuestionMarks,
		UserID,	
		Created,
		Modified
	)
	VALUES
	(
		@QuestionText,
		@QuestionLevelID,
		@OptionA,
		@OptionB,
		@OptionC,
		@OptionD,
		@CorrectOption,
		@QuestionMarks,
		@UserID,
		@Created,
		@Modified
	)
END
GO

-- %% [markdown]
-- # [dbo].[PR_MST_Question_Search]

-- %%
/****** Object:  StoredProcedure [dbo].[PR_MST_Question_Search]    Script Date: 07-03-2025 10:30:55 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[PR_MST_Question_Search]
    @QuestionLevel INT = NULL,
    @QuestionText NVARCHAR(MAX) = NULL,
    @QuestionMarks INT = NULL
AS
BEGIN
    SELECT
        Q.QuestionID,
        Q.QuestionText,
        Q.QuestionLevelID,
		L.QuestionLevel,
        Q.OptionA, Q.OptionB, Q.OptionC, Q.OptionD,
        Q.CorrectOption,
        Q.QuestionMarks,
        Q.IsActive,
        Q.UserID,
        U.UserName,
        Q.Created, Q.Modified
    FROM MST_Question Q
    INNER JOIN MST_QuestionLevel L ON Q.QuestionLevelID = L.QuestionLevelID
    INNER JOIN MST_User U ON Q.UserID = U.UserID
    WHERE
        (@QuestionLevel IS NULL OR Q.QuestionLevelID = @QuestionLevel)
        AND (@QuestionText IS NULL OR Q.QuestionText LIKE '%' + @QuestionText + '%')
        AND (@QuestionMarks IS NULL OR Q.QuestionMarks = @QuestionMarks);
END
GO

-- %% [markdown]
-- # [dbo].[PR_MST_Question_SelectAll]

-- %%
/****** Object:  StoredProcedure [dbo].[PR_MST_Question_SelectAll]    Script Date: 07-03-2025 10:30:55 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[PR_MST_Question_SelectAll]
@UserID INT

AS
BEGIN
	SELECT 
		[MST_Question].QuestionId,
		[MST_Question].QuestionText,
		[MST_Question].QuestionLevelID,
		[MST_QuestionLevel].QuestionLevel,
		[MST_Question].OptionA,
		[MST_Question].OptionB,
		[MST_Question].OptionC,
		[MST_Question].OptionD,
		[MST_Question].CorrectOption,
		[MST_Question].QuestionMarks,
		[MST_Question].IsActive,
		[MST_Question].UserID,
		[MST_User].UserName,
		[MST_Question].Created,
		[MST_Question].Modified,
		[MST_QuestionLevel].[QuestionLevel]
	FROM [MST_Question]
	INNER JOIN [MST_QuestionLevel] ON [MST_QuestionLevel].QuestionLevelID = [MST_Question].QuestionLevelID
	INNER JOIN [MST_User] ON [MST_User].[UserID] = [MST_Question].[UserID]
	WHERE [MST_Question].UserID = @UserID
	ORDER BY [MST_Question].QuestionID
END
GO

-- %% [markdown]
-- # [dbo].[PR_MST_Question_SelectByPK]

-- %%
/****** Object:  StoredProcedure [dbo].[PR_MST_Question_SelectByPK]    Script Date: 07-03-2025 10:30:55 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[PR_MST_Question_SelectByPK]
	@QuestionID INT
AS
BEGIN
	SELECT 
		[MST_Question].QuestionId,
		[MST_Question].QuestionText,
		[MST_Question].QuestionLevelID,
		[MST_Question].OptionA,
		[MST_Question].OptionB,
		[MST_Question].OptionC,
		[MST_Question].OptionD,
		[MST_Question].CorrectOption,
		[MST_Question].QuestionMarks,
		[MST_Question].IsActive,
		[MST_Question].UserID,
		[MST_Question].Created,
		[MST_Question].Modified
	FROM [MST_Question]	
	WHERE [MST_Question].QuestionId = @QuestionID
	ORDER BY [MST_Question].QuestionID
END
GO

-- %% [markdown]
-- # [dbo].[PR_MST_Question_TopTen]

-- %%
/****** Object:  StoredProcedure [dbo].[PR_MST_Question_TopTen]    Script Date: 07-03-2025 10:30:55 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[PR_MST_Question_TopTen]
@UserID INT
AS
BEGIN
	SELECT TOP 10
		[MST_Question].QuestionId,
		[MST_Question].QuestionText,
		[MST_Question].QuestionLevelID,
		[MST_Question].OptionA,
		[MST_Question].OptionB,
		[MST_Question].OptionC,
		[MST_Question].OptionD,
		[MST_Question].CorrectOption,
		[MST_Question].QuestionMarks,
		[MST_Question].IsActive,
		[MST_Question].UserID,
		[MST_Question].Created,
		[MST_Question].Modified,
		[MST_QuestionLevel].[QuestionLevel]
	FROM [MST_Question]
	INNER JOIN [MST_QuestionLevel] ON [MST_QuestionLevel].QuestionLevelID = [MST_Question].QuestionLevelID
	INNER JOIN [MST_User] ON [MST_User].[UserID] = [MST_Question].[UserID]
	WHERE [MST_Question].UserID = @UserID
	ORDER BY [MST_Question].Created DESC
END
GO

-- %% [markdown]
-- # [dbo].[PR_MST_Question_UpdateByPk]

-- %%
/****** Object:  StoredProcedure [dbo].[PR_MST_Question_UpdateByPk]    Script Date: 07-03-2025 10:30:55 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[PR_MST_Question_UpdateByPk]
	@QuestionID			INT,
	@QuestionText		NVARCHAR(50),
	@QuestionLevelID	INT,
	@OptionA			NVARCHAR(50),
	@OptionB			NVARCHAR(50),
	@OptionC			NVARCHAR(50),
	@OptionD			NVARCHAR(50),
	@CorrectOption		NVARCHAR(50),
	@QuestionMarks		INT,
	@UserID				INT,
	@Modified			DATETIME
AS
BEGIN
	UPDATE [MST_Question] 
	SET
		[MST_Question].[QuestionText]		= @QuestionText,
		[MST_Question].[QuestionLevelID]	= @QuestionLevelID,
		[MST_Question].[OptionA]			= @OptionA,
		[MST_Question].[OptionB]			= @OptionB,
		[MST_Question].[OptionC]			= @OptionC,
		[MST_Question].[OptionD]			= @OptionD,
		[MST_Question].[CorrectOption]		= @CorrectOption,
		[MST_Question].[QuestionMarks]		= @QuestionMarks,
		[MST_Question].[UserID]				= @UserID,
		[MST_Question].[Modified]			= @Modified
	WHERE [MST_Question].QuestionID			= @QuestionID
END
GO

-- %% [markdown]
-- # [dbo].[PR_MST_QuestionDropDown]

-- %%
/****** Object:  StoredProcedure [dbo].[PR_MST_QuestionDropDown]    Script Date: 07-03-2025 10:30:55 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[PR_MST_QuestionDropDown]
AS
BEGIN 
	
	SELECT 
		QuestionID,
		QuestionText
	From [MST_Question] 
	ORDER BY QuestionText
END
GO

-- %% [markdown]
-- # [dbo].[PR_MST_QuestionLevel_Count]

-- %%
/****** Object:  StoredProcedure [dbo].[PR_MST_QuestionLevel_Count]    Script Date: 07-03-2025 10:30:55 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[PR_MST_QuestionLevel_Count]
@UserID INT

AS
BEGIN 
		SELECT COUNT([MST_QuestionLevel].QuestionLevelID) as 'Count'
		FROM [MST_QuestionLevel]
		WHERE [MST_QuestionLevel].UserID = @UserID

		
END
GO

-- %% [markdown]
-- # [dbo].[PR_MST_QuestionLevel_DeleteByPk]

-- %%
/****** Object:  StoredProcedure [dbo].[PR_MST_QuestionLevel_DeleteByPk]    Script Date: 07-03-2025 10:30:55 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[PR_MST_QuestionLevel_DeleteByPk]
    @QuestionLevelID INT
AS
BEGIN
    DELETE FROM [dbo].[MST_QuestionLevel]
    WHERE [dbo].[MST_QuestionLevel].[QuestionLevelID] = @QuestionLevelID;
END
GO

-- %% [markdown]
-- # [dbo].[PR_MST_QuestionLevel_Insert]

-- %%
/****** Object:  StoredProcedure [dbo].[PR_MST_QuestionLevel_Insert]    Script Date: 07-03-2025 10:30:55 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[PR_MST_QuestionLevel_Insert]
    @QuestionLevel  NVARCHAR(50),
    @UserID			INT,
    @Created		DATETIME,
	@Modified		DATETIME
AS
BEGIN
    INSERT INTO [MST_QuestionLevel]
	(
		QuestionLevel,
		UserID,
		Created,
		Modified
	)
	VALUES 
	(
		@QuestionLevel,
		@UserID, 
		@Created, 
		@Modified
	);
END
GO

-- %% [markdown]
-- # [dbo].[PR_MST_QuestionLevel_SelectAll]

-- %%
/****** Object:  StoredProcedure [dbo].[PR_MST_QuestionLevel_SelectAll]    Script Date: 07-03-2025 10:30:55 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[PR_MST_QuestionLevel_SelectAll]
@UserID INT
AS
BEGIN
   SELECT  [MST_QuestionLevel].[QuestionLevelID], 
		   [MST_QuestionLevel].[QuestionLevel], 
           [MST_QuestionLevel].[UserID], 
		   [MST_User].[UserName],
		   [MST_QuestionLevel].[Created],
		   [MST_QuestionLevel].[Modified]
    FROM [MST_QuestionLevel]
	INNER JOIN [MST_User] ON [MST_User].UserID = [MST_QuestionLevel].UserID
	WHERE [MST_QuestionLevel].UserID = @UserID
    ORDER BY [MST_QuestionLevel].QuestionLevel
END
GO

-- %% [markdown]
-- # [dbo].[PR_MST_QuestionLevel_SelectByPk]

-- %%
/****** Object:  StoredProcedure [dbo].[PR_MST_QuestionLevel_SelectByPk]    Script Date: 07-03-2025 10:30:55 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[PR_MST_QuestionLevel_SelectByPk]
    @QuestionLevelID INT
AS
BEGIN
    SELECT [MST_QuestionLevel].[QuestionLevelID], 
		   [MST_QuestionLevel].[QuestionLevel], 
           [MST_QuestionLevel].[UserID], 
		   [MST_QuestionLevel].[Created],
		   [MST_QuestionLevel].[Modified]
    FROM [MST_QuestionLevel]
    WHERE [MST_QuestionLevel].QuestionLevelID = @QuestionLevelID
    ORDER BY [MST_QuestionLevel].QuestionLevel
END
GO

-- %% [markdown]
-- # [dbo].[PR_MST_QuestionLevel_UpdateByPk]

-- %%
/****** Object:  StoredProcedure [dbo].[PR_MST_QuestionLevel_UpdateByPk]    Script Date: 07-03-2025 10:30:55 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[PR_MST_QuestionLevel_UpdateByPk]
	@QuestionLevelID	INT,
	@QuestionLevel		NVARCHAR(50),
    @UserID				INT,
	@Modified			DATETIME
AS
BEGIN
    UPDATE [MST_QuestionLevel]
    SET   
		 [dbo].[MST_QuestionLevel].[QuestionLevel]		= @QuestionLevel, 
         [dbo].[MST_QuestionLevel].[UserID]				= @UserID, 
		 [dbo].[MST_QuestionLevel].[Modified]			= @Modified
   WHERE [dbo].[MST_QuestionLevel].[QuestionLevelID]	= @QuestionLevelID
END
GO

-- %% [markdown]
-- # [dbo].[PR_MST_QuestionLevelDropDown]

-- %%
/****** Object:  StoredProcedure [dbo].[PR_MST_QuestionLevelDropDown]    Script Date: 07-03-2025 10:30:55 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[PR_MST_QuestionLevelDropDown]
AS
BEGIN 
	SELECT 
		QuestionLevelID,
		QuestionLevel
	From [MST_QuestionLevel] 
	ORDER BY QuestionLevel
END
GO

-- %% [markdown]
-- # [dbo].[PR_MST_Quiz_Count]

-- %%
/****** Object:  StoredProcedure [dbo].[PR_MST_Quiz_Count]    Script Date: 07-03-2025 10:30:55 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[PR_MST_Quiz_Count]
@UserID INT
AS
BEGIN 
		SELECT COUNT([MST_Quiz].QuizID) as 'Count'
		FROM [MST_Quiz]
		WHERE [MST_Quiz].UserID = @UserID
END
GO

-- %% [markdown]
-- # [dbo].[PR_MST_Quiz_DeleteByPk]

-- %%
/****** Object:  StoredProcedure [dbo].[PR_MST_Quiz_DeleteByPk]    Script Date: 07-03-2025 10:30:55 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[PR_MST_Quiz_DeleteByPk]
	@QuizID INT
AS
BEGIN
	DELETE FROM [MST_Quiz]
	WHERE [MST_Quiz].QuizID = @QuizId
END
GO

-- %% [markdown]
-- # [dbo].[PR_MST_Quiz_Insert]

-- %%
/****** Object:  StoredProcedure [dbo].[PR_MST_Quiz_Insert]    Script Date: 07-03-2025 10:30:55 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[PR_MST_Quiz_Insert]
	@QuizName			NVARCHAR(50),
    @TotalQuestions		NVARCHAR(50),
	@QuizDate			DATETIME,
    @UserID				INT,
    @Created			DATETIME,
    @Modified			DATETIME
AS
BEGIN
    INSERT INTO [MST_Quiz] 
	(
		QuizName,
		TotalQuestions,
		QuizDate,
		UserID,
		Created,
		Modified
	)
	VALUES 
	(
		@QuizName,
		@TotalQuestions,
		@QuizDate,
		@UserID, 
		@Created, 
		@Modified
	);
END
GO

-- %% [markdown]
-- # [dbo].[PR_MST_Quiz_SelectAll]

-- %%
/****** Object:  StoredProcedure [dbo].[PR_MST_Quiz_SelectAll]    Script Date: 07-03-2025 10:30:55 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[PR_MST_Quiz_SelectAll]
@UserID INT
AS
BEGIN
	SELECT 
		[MST_Quiz].QuizID,
		[MST_Quiz].QuizName,
		[MST_Quiz].TotalQuestions,
		[MST_Quiz].QuizDate,
		[MST_Quiz].UserID,
		[MST_User].UserName,
		[MST_Quiz].Created,
		[MST_Quiz].Modified
	FROM [MST_Quiz]
	INNER JOIN [MST_User] ON [MST_User].UserID = [MST_Quiz].UserID
	WHERE [MST_Quiz].UserID = @UserID
	ORDER BY [MST_Quiz].QuizName
END
GO

-- %% [markdown]
-- # [dbo].[PR_MST_Quiz_SelectByID]

-- %%
/****** Object:  StoredProcedure [dbo].[PR_MST_Quiz_SelectByID]    Script Date: 07-03-2025 10:30:55 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[PR_MST_Quiz_SelectByID]
	@QuizID INT
AS
BEGIN
	SELECT 
		[MST_Quiz].QuizID,
		[MST_Quiz].QuizName,
		[MST_Quiz].TotalQuestions,
		[MST_Quiz].QuizDate,
		[MST_Quiz].UserID
	FROM [MST_Quiz]
	WHERE [MST_Quiz].QuizID = @QuizID
	ORDER BY [MST_Quiz].QuizName
END
GO

-- %% [markdown]
-- # [dbo].[PR_MST_Quiz_TopTen]

-- %%
/****** Object:  StoredProcedure [dbo].[PR_MST_Quiz_TopTen]    Script Date: 07-03-2025 10:30:55 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[PR_MST_Quiz_TopTen]
@UserID INT

AS
BEGIN
	SELECT TOP 10
		[MST_Quiz].QuizID,
		[MST_Quiz].QuizName,
		[MST_Quiz].TotalQuestions,
		[MST_Quiz].QuizDate,
		[MST_Quiz].UserID,
		[MST_User].UserName,
		[MST_Quiz].Created,
		[MST_Quiz].Modified
	FROM [MST_Quiz]
	INNER JOIN [MST_User] ON [MST_User].UserID = [MST_Quiz].UserID
			WHERE [MST_Quiz].UserID = @UserID
	ORDER BY [MST_Quiz].Created DESC
END
GO

-- %% [markdown]
-- # [dbo].[PR_MST_Quiz_UpdateByPK]

-- %%
/****** Object:  StoredProcedure [dbo].[PR_MST_Quiz_UpdateByPK]    Script Date: 07-03-2025 10:30:55 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[PR_MST_Quiz_UpdateByPK]
	@QuizID				INT,
	@QuizName			NVARCHAR(50),
    @TotalQuestions		NVARCHAR(50),
	@QuizDate			DATETIME,
    @UserID				INT,
    @Modified			DATETIME
AS
BEGIN
   UPDATE [MST_Quiz] 
   SET
		[MST_Quiz].QuizName			= @QuizName,
		[MST_Quiz].TotalQuestions	= @TotalQuestions,
		[MST_Quiz].QuizDate			= @QuizDate,
		[MST_Quiz].UserID			= @UserID,
		[MST_Quiz].Modified			= @Modified
		WHERE [MST_Quiz].QuizID		= @QuizID
END
GO

-- %% [markdown]
-- # [dbo].[PR_MST_QuizDropDown]

-- %%
/****** Object:  StoredProcedure [dbo].[PR_MST_QuizDropDown]    Script Date: 07-03-2025 10:30:55 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[PR_MST_QuizDropDown]
AS
BEGIN 
	
	SELECT 
		QuizID,
		QuizName
	From [MST_Quiz] 
	ORDER BY QuizName
END
GO

-- %% [markdown]
-- # [dbo].[PR_MST_QuizQuestionsWise_DeleteByPk]

-- %%
/****** Object:  StoredProcedure [dbo].[PR_MST_QuizQuestionsWise_DeleteByPk]    Script Date: 07-03-2025 10:30:55 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[PR_MST_QuizQuestionsWise_DeleteByPk]
    @QuizWiseQuestionsID INT
AS
BEGIN
    DELETE FROM [dbo].[MST_QuizWiseQuestions]
    WHERE [dbo].[MST_QuizWiseQuestions].[QuizWiseQuestionsID] = @QuizWiseQuestionsID;
END
GO

-- %% [markdown]
-- # [dbo].[PR_MST_QuizQuestionsWise_Insert]

-- %%
/****** Object:  StoredProcedure [dbo].[PR_MST_QuizQuestionsWise_Insert]    Script Date: 07-03-2025 10:30:55 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[PR_MST_QuizQuestionsWise_Insert]
	@QuizID			INT,
    @QuestionID		INT,
    @UserID			INT,
    @Created		DATETIME,
	@Modified		DATETIME
AS
BEGIN
    INSERT INTO [MST_QuizWiseQuestions] 
	(
		QuizID,
		QuestionID,
		UserID,
		Created,
		Modified
	)
	VALUES 
	(
		@QuizID,
		@QuestionID, 
		@UserID,
		@Created,
		@Modified
	);
END
GO

-- %% [markdown]
-- # [dbo].[PR_MST_QuizQuestionsWise_SelectAll]

-- %%
/****** Object:  StoredProcedure [dbo].[PR_MST_QuizQuestionsWise_SelectAll]    Script Date: 07-03-2025 10:30:55 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[PR_MST_QuizQuestionsWise_SelectAll]
AS
BEGIN
     SELECT [MST_QuizWiseQuestions].[QuizWiseQuestionsID], 
			[MST_QuizWiseQuestions].[QuizID], 
			[MST_Quiz].QuizName,
			[MST_QuizWiseQuestions].[QuestionID],
			[MST_Question].QuestionText,
			[MST_QuizWiseQuestions].[UserID], 
			[MST_User].UserName,
			[MST_QuizWiseQuestions].[Created],
			[MST_QuizWiseQuestions].[Modified]
    FROM [MST_QuizWiseQuestions]
	INNER JOIN [MST_Quiz] ON [MST_QuizWiseQuestions].QuizID = [MST_QuizWiseQuestions].QuizID
	INNER JOIN [MST_Question] ON [MST_Question].QuestionID = [MST_QuizWiseQuestions].QuestionID
	INNER JOIN [MST_User] ON [MST_User].UserID = [MST_QuizWiseQuestions].UserID
    ORDER BY [MST_QuizWiseQuestions].[QuizWiseQuestionsID];
END
GO

-- %% [markdown]
-- # [dbo].[PR_MST_QuizQuestionsWise_SelectByPk]

-- %%
/****** Object:  StoredProcedure [dbo].[PR_MST_QuizQuestionsWise_SelectByPk]    Script Date: 07-03-2025 10:30:55 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[PR_MST_QuizQuestionsWise_SelectByPk]
    @QuizWiseQuestionsID INT
AS
BEGIN
    SELECT [MST_QuizWiseQuestions].[QuizWiseQuestionsID], 
		   [MST_QuizWiseQuestions].[QuizID], 
           [MST_QuizWiseQuestions].[QuestionID], 
		   [MST_QuizWiseQuestions].[UserID], 
		   [MST_QuizWiseQuestions].[Created],
		   [MST_QuizWiseQuestions].[Modified]
    FROM  [MST_QuizWiseQuestions]
    WHERE [MST_QuizWiseQuestions].[QuizWiseQuestionsID] = @QuizWiseQuestionsID
    ORDER BY [MST_QuizWiseQuestions].[QuizWiseQuestionsID];
END
GO

-- %% [markdown]
-- # [dbo].[PR_MST_QuizQuestionsWise_UpdateByPk]

-- %%
/****** Object:  StoredProcedure [dbo].[PR_MST_QuizQuestionsWise_UpdateByPk]    Script Date: 07-03-2025 10:30:55 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[PR_MST_QuizQuestionsWise_UpdateByPk]
	@QuizWiseQuestionsID	INT,
	@QuizID					INT,
    @QuestionID				INT,
    @UserID					INT,
    @Created				DATETIME,
	@Modified				DATETIME
AS
BEGIN
    UPDATE [MST_QuizWiseQuestions]
    SET  [dbo].[MST_QuizWiseQuestions].[QuizID]					= @QuizID, 
         [dbo].[MST_QuizWiseQuestions].[QuestionID]				= @QuestionID, 
         [dbo].[MST_QuizWiseQuestions].[UserID]					= @UserID, 
		 [dbo].[MST_QuizWiseQuestions].[Created]				= @Created
   WHERE [dbo].[MST_QuizWiseQuestions].[QuizWiseQuestionsID]	= @QuizWiseQuestionsID;
END
GO

-- %% [markdown]
-- # [dbo].[PR_MST_User_DeleteByPk]

-- %%
/****** Object:  StoredProcedure [dbo].[PR_MST_User_DeleteByPk]    Script Date: 07-03-2025 10:30:55 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[PR_MST_User_DeleteByPk]
    @UserID INT
AS
BEGIN
    DELETE FROM [dbo].[MST_User]
    WHERE [dbo].[MST_User].[UserID] = @UserID;
END
GO

-- %% [markdown]
-- # [dbo].[PR_MST_User_Insert]

-- %%
/****** Object:  StoredProcedure [dbo].[PR_MST_User_Insert]    Script Date: 07-03-2025 10:30:55 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[PR_MST_User_Insert]
	@UserName  NVARCHAR(50),
    @Password  NVARCHAR(50),
    @Email  NVARCHAR(50),
    @Mobile NVARCHAR(50),
    @IsActive BIT,
	@IsAdmin BIT,
    @Created DATETIME,
	@Modified DATETIME
AS
BEGIN
    INSERT INTO [MST_User] (UserName,Password,Email,Mobile,IsActive,IsAdmin,Created,Modified)
	VALUES (@UserName,@Password, @Email, @Mobile, @IsActive,@IsAdmin, @Created, @Modified);
END
GO

-- %% [markdown]
-- # [dbo].[PR_MST_User_Login]

-- %%
/****** Object:  StoredProcedure [dbo].[PR_MST_User_Login]    Script Date: 07-03-2025 10:30:55 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[PR_MST_User_Login]  
@UserName  NVARCHAR(50),  
@Password  NVARCHAR(50)  
AS  
BEGIN  
 SELECT   
  UserID,
  Username
 FROM [MST_User]  
 WHERE   
 (Username = @UserName OR Email = @UserName OR Mobile = @UserName)  
 AND Password = @Password  
END
GO

-- %% [markdown]
-- # [dbo].[PR_MST_User_SelectAll]

-- %%
/****** Object:  StoredProcedure [dbo].[PR_MST_User_SelectAll]    Script Date: 07-03-2025 10:30:55 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[PR_MST_User_SelectAll]
AS
BEGIN
    SELECT [MST_User].[UserID], 
           [MST_User].[UserName], 
           [MST_User].[Password], 
		   [MST_User].[Email], 
           [MST_User].[Mobile], 
           [MST_User].[IsActive],
		   [MST_User].[IsAdmin],
		   [MST_User].[Created],
		   [MST_User].[Modified]
    FROM [MST_User]
    ORDER BY [MST_User].UserName
END

GO

-- %% [markdown]
-- # [dbo].[PR_MST_User_SelectByPK]

-- %%
/****** Object:  StoredProcedure [dbo].[PR_MST_User_SelectByPK]    Script Date: 07-03-2025 10:30:55 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[PR_MST_User_SelectByPK]
    @UserID INT
AS
BEGIN
    SELECT [MST_User].UserID, 
		   [MST_User].UserName, 
           [MST_User].Password, 
		   [MST_User].Email, 
           [MST_User].Mobile, 
           [MST_User].IsActive,
		   [MST_User].IsAdmin,
		   [MST_User].Created,
		   [MST_User].Modified
    FROM [MST_User]
    WHERE [MST_User].[UserID] = @UserID
    ORDER BY [MST_User].[UserID];
END
GO

-- %% [markdown]
-- # [dbo].[PR_MST_User_UpdateByPk]

-- %%
/****** Object:  StoredProcedure [dbo].[PR_MST_User_UpdateByPk]    Script Date: 07-03-2025 10:30:55 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[PR_MST_User_UpdateByPk]
	@UserID		INT,
	@UserName	NVARCHAR(50),
    @Password	NVARCHAR(50),
    @Email		NVARCHAR(50),
    @Mobile		NVARCHAR(50),
    @IsActive	BIT,
	@IsAdmin	BIT,
    @Created	DATETIME,
	@Modified	DATETIME
AS
BEGIN
    UPDATE [MST_User]
    SET  [dbo].[MST_User].[UserName]	= @UserName, 
         [dbo].[MST_User].[Password]	= @Password, 
         [dbo].[MST_User].[Email]		= @Password, 
         [dbo].[MST_User].[Mobile]		= @Email, 
         [dbo].[MST_User].[IsActive]	= @IsActive,
		 [dbo].[MST_User].[IsAdmin]		= @IsAdmin,
		 [dbo].[MST_User].[Created]		= @Created
   WHERE [dbo].[MST_User].[UserID]		= @UserID;
END
GO

-- %% [markdown]
-- # [Quiz_Management]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [Quiz_Management] SET  READ_WRITE 
GO
